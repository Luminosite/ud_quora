# %%
import features as ft
# ft.gen_feature(n=540000, data_file="test.csv", start=270000)
# Out:
# S:\anaconda\envs\tf\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
#ft.gen_feature(n=1800000, data_file="test.csv", start=810000)

# %%
ft.gen_feature(n=3563475, data_file="test.csv", start=2700000)
# Out:
# generate the data for dist_features_test_2700000_3563475
# generate the data for norm_wmd_feature_test_2700000_3563475
# generate the data for wmd_feature_test_2700000_3563475
# generate the data for basic_feature_test_2700000_3563475
# E:\quora\ud_quora\features.py:52: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   parameter = r_or_g_by_list_n(l, i-1)
# basic data is ready
# data for basic_feature_test_2700000_3563475 generated
# data for wmd_feature_test_2700000_3563475 generated
# data for norm_wmd_feature_test_2700000_3563475 generated
# 0it [00:00, ?it/s]E:\quora\ud_quora\features.py:129: RuntimeWarning: invalid value encountered in double_scalars
#   return v / np.sqrt((v ** 2).sum())
# 863475it [03:50, 3751.79it/s]
# 863475it [03:48, 3771.46it/s]
# S:\anaconda\envs\tf\lib\site-packages\scipy\spatial\distance.py:698: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)
# ...

# %%
import pandas as pd

data = pd.read_csv("data/test.csv", sep=",")
# Out:
# S:\anaconda\envs\tf\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.shape
# Out:
# (3563475, 3)

# %%
import pandas as pd
import numpy as np

a = pd.DataFrame([[3, np.inf, 1, 2], [np.inf, 9, 3, 4], [1, 1, 1, 1], [2, 2, 2, 2]])
a
# Out:
#           0         1  2  3
# 0  3.000000       inf  1  2
# 1       inf  9.000000  3  4
# 2  1.000000  1.000000  1  1
# 3  2.000000  2.000000  2  2

# %%
a[a!=np.inf].dropna()
# Out:
#      0    1  2  3
# 2  1.0  1.0  1  1
# 3  2.0  2.0  2  2

# %%
import nltk
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /Users/kunfu/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True
