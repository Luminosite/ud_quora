# %%
import features_mp as ft
ft.gen_transferred_dist_feature(data_file="test.csv")
# Out:
# S:\anaconda\envs\tf\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# generate the data for nmf30_features_test
# generate the data for svd25_features_test
# generate the data for svd300_features_test
# read the data for common_ratio_features_test
# E:\quora\ud_quora\features_mp.py:77: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   parameter = r_or_g_by_list_n(l, i-1)
# data for common_ratio_features_test read
# process topic model starts with 2 processes 9 jobs
# data list size: 9
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "S:\anaconda\envs\tf\lib\multiprocessing\pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "S:\anaconda\envs\tf\lib\multiprocessing\pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "E:\quora\ud_quora\features_mp.py", line 375, in svd300
#     return transfer_vec_cal_dist(d, (TruncatedSVD, [300]))
#   File "E:\quora\ud_quora\features_mp.py", line 357, in transfer_vec_cal_dist
#     tfidf = tfidf_gen(data)
#   File "E:\quora\ud_quora\features_mp.py", line 325, in tfidf_gen
#     vect_orig.fit(corpus)
#   File "S:\anaconda\envs\tf\lib\site-packages\sklearn\feature_extraction\text.py", line 1584, in fit
#     X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#   File "S:\anaconda\envs\tf\lib\site-packages\sklearn\feature_extraction\text.py", line 1032, in fit_transform
#     self.fixed_vocabulary_)
#   File "S:\anaconda\envs\tf\lib\site-packages\sklearn\feature_extraction\text.py", line 961, in _count_vocab
#     raise ValueError("empty vocabulary; perhaps the documents only"
# ValueError: empty vocabulary; perhaps the documents only contain stop words
# """
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-a0ab1d3dd209> in <module>
#       1 import features_mp as ft
# ----> 2 ft.gen_transferred_dist_feature(data_file="test.csv")
#
# E:\quora\ud_quora\features_mp.py in gen_transferred_dist_feature(n, data_file, start)
#     493
#     494 def gen_transferred_dist_feature(n=0, data_file="train.csv", start=0):
# --> 495     return feature_generation(n=n, data_file=data_file, start=start, operation_list=operations[:8])
#     496
#     497
#
# E:\quora\ud_quora\features_mp.py in feature_generation(n, data_file, start, operation_list)
#     488         full_tag = base_name + tag
#     489         ops.append((full_tag, gen_func))
# --> 490     features_data = read_or_gen_by_list(ops)
#     491     return features_data
#     492
#
# E:\quora\ud_quora\features_mp.py in read_or_gen_by_list(l)
#      57         print("Error: input list is empty")
#      58         return None
# ---> 59     return r_or_g_by_list_n(l, current)
#      60
#      61
#
# E:\quora\ud_quora\features_mp.py in r_or_g_by_list_n(l, i)
#      75             d = func()
#      76         else:
# ---> 77             parameter = r_or_g_by_list_n(l, i-1)
#      78             d = func(parameter)
#      79         d.to_csv(path, index=False)
#
# E:\quora\ud_quora\features_mp.py in r_or_g_by_list_n(l, i)
#      75             d = func()
#      76         else:
# ---> 77             parameter = r_or_g_by_list_n(l, i-1)
#      78             d = func(parameter)
#      79         d.to_csv(path, index=False)
#
# E:\quora\ud_quora\features_mp.py in r_or_g_by_list_n(l, i)
#      76         else:
#      77             parameter = r_or_g_by_list_n(l, i-1)
# ---> 78             d = func(parameter)
#      79         d.to_csv(path, index=False)
#      80         print("data for {name} generated".format(name=name))
#
# E:\quora\ud_quora\features_mp.py in svd300_feature(data)
#     376 def svd300_feature(data):
#     377     data_block_number = int( (data.shape[0]-1) / block_size ) + 1
# --> 378     process_data(svd300, data, n=2, tag='topic model', data_n=data_block_number)
#     379     return data
#     380
#
# E:\quora\ud_quora\poolprocess.py in process_data(func, data, n, tag, data_n)
#      20     print('data list size:', len(data_list))
#      21     pool = Pool(n)
# ---> 22     ret = pool.map(func, data_list)
#      23     pool.close()
#      24     pool.join()
#
# S:\anaconda\envs\tf\lib\multiprocessing\pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# S:\anaconda\envs\tf\lib\multiprocessing\pool.py in get(self, timeout)
#     655             return self._value
#     656         else:
# --> 657             raise self._value
#     658
#     659     def _set(self, i, obj):
#
# ValueError: empty vocabulary; perhaps the documents only contain stop words

# %%
import pandas as pd
import numpy as np

test_ranges = [
      (0,        270000)
     ,(270000,   540000)
     ,(540000,   810000)
     ,(810000,  1800000)
#     ,(1800000,  2700000)
    ,(2700000,  3563475)
]

features = ['test_id', 'len_q1', 'len_q2', 'diff_len', 'len_char_q1', 'len_char_q2', 'len_word_q1', 'len_word_q2',
           'common_words', 'fuzz_qratio', 'fuzz_WRatio', 'fuzz_partial_ratio',
           'fuzz_partial_token_set_ratio', 'fuzz_partial_token_sort_ratio',
           'fuzz_token_set_ratio', 'fuzz_token_sort_ratio', 'wmd', 'norm_wmd',
           'cosine_distance', 'cityblock_distance', 'jaccard_distance',
           'canberra_distance', 'euclidean_distance', 'minkowski_distance',
           'braycurtis_distance', 'skew_q1vec', 'skew_q2vec', 'kur_q1vec',
           'kur_q2vec']

model_features = ['len_q1', 'len_q2', 'diff_len', 'len_char_q1', 'len_char_q2', 'len_word_q1', 'len_word_q2',
           'common_words', 'fuzz_qratio', 'fuzz_WRatio', 'fuzz_partial_ratio',
           'fuzz_partial_token_set_ratio', 'fuzz_partial_token_sort_ratio',
           'fuzz_token_set_ratio', 'fuzz_token_sort_ratio', 'wmd', 'norm_wmd',
           'cosine_distance', 'cityblock_distance', 'jaccard_distance',
           'canberra_distance', 'euclidean_distance', 'minkowski_distance',
           'braycurtis_distance', 'skew_q1vec', 'skew_q2vec', 'kur_q1vec',
           'kur_q2vec']

def prepare_test_data(data_tuple):
    start, end = data_tuple
    t_data = ft.gen_feature(n=end, data_file="test.csv", start=start)
    
    feature_data = t_data
    input_data = feature_data[model_features]
    input_data = input_data.replace([np.inf, -np.inf], 100).fillna(0).astype(np.float64)
    input_data['test_id'] = feature_data['test_id']
    return input_data

# %%
def cal_result(tuple):
    df = prepare_test_data(tuple)
    df['is_duplicate'] = clf.predict(df[model_features])
    result = df[['test_id', 'is_duplicate']]
    return result

results = [cal_result(x) for x in test_ranges]
# Out:
# read the data for dist_features_test_0_270000
# data for dist_features_test_0_270000 read
# read the data for dist_features_test_270000_540000
# data for dist_features_test_270000_540000 read
# read the data for dist_features_test_540000_810000
# data for dist_features_test_540000_810000 read
# read the data for dist_features_test_810000_1800000
# data for dist_features_test_810000_1800000 read
# read the data for dist_features_test_2700000_3563475
# data for dist_features_test_2700000_3563475 read

# %%
results[0]
# Out:
#         test_id  is_duplicate
# 0             0             0
# 1             1             1
# 2             2             1
# 3             3             0
# 4             4             0
# 5             5             0
# 6             6             1
# 7             7             0
# 8             8             1
# 9             9             0
# 10           10             0
# 11           11             0
# 12           12             0
# 13           13             0
# 14           14             0
# 15           15             0
# 16           16             0
# 17           17             1
# 18           18             1
# 19           19             1
# 20           20             0
# 21           21             0
# 22           22             0
# 23           23             0
# 24           24             0
# 25           25             0
# 26           26             0
# 27           27             0
# 28           28             0
# 29           29             0
# ...         ...           ...
# 269970   269970             0
# 269971   269971             0
# 269972   269972             0
# 269973   269973             0
# 269974   269974             0
# 269975   269975             0
# 269976   269976             0
# 269977   269977             0
# 269978   269978             0
# 269979   269979             0
# 269980   269980             0
# 269981   269981             0
# 269982   269982             0
# 269983   269983             1
# 269984   269984             0
# 269985   269985             0
# 269986   269986             0
# 269987   269987             0
# 269988   269988             0
# 269989   269989             0
# 269990   269990             0
# 269991   269991             0
# 269992   269992             0
# 269993   269993             0
# 269994   269994             0
# 269995   269995             0
# 269996   269996             0
# 269997   269997             1
# 269998   269998             0
# 269999   269999             0
#
# [270000 rows x 2 columns]

# %%
all = pd.concat(results)
all.to_csv("data/result_less.csv", index=False)

# %%
drop = all.drop_duplicates(['test_id'], keep='last')
drop.to_csv("data/result_less.csv", index=False)

# %%
single = results[0]
single = single.drop_duplicates(['test_id'], keep='last')
single.to_csv("data/submission.csv", index=False)

# %%
l  =['a','b']
for i,n in enumerate(l):
    print(i,n)
# Out:
# 0 a
# 1 b
